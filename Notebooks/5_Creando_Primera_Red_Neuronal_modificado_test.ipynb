# %% [markdown]
# <h1><center>Redes Neuronales con Keras y Scikit</center></h1>
#
#
# <center><i>Creando nuestra primera red neuronal</i></center>

# %% [markdown]
# # <h1>Contenido</h1>
#
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#     <ol>
#         <li><a href="#problema">Contexto Analítico</a></li>
#         <li><a href="#arquitectura">Arquitectura propuesta</a></li>
#         <li><a href="#keras">Entrenamiento y Evaluación del Modelo</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# # <h1 id="problema">Contexto analítico</h1>
#
# Requerimos diseñar un modelo que permita determinar el precio medio de las viviendas en Boston, para ello contamos con un set de información disponible en Keras con características y precios de viviendas en diferentes ubicaciones de Boston de finales de 1970. (Mayor detalle disponible en http://lib.stat.cmu.edu/datasets/boston
#
# En total contamos con 506 muestras caracterizadas por 13 variables.

# %% [markdown]
#  Variables | Description
#  --- | ---
#  CRIM   |  per capita crime rate by town
#  ZN     |  proportion of residential land zoned for lots over 25,000 sq.ft.
#  INDUS  |  proportion of non-retail business acres per town
#  CHAS   |  Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#  NOX    |  nitric oxides concentration (parts per 10 million)
#  RM     |  average number of rooms per dwelling
#  AGE    |  proportion of owner-occupied units built prior to 1940
#  DIS    |  weighted distances to five Boston employment centres
#  RAD    |  index of accessibility to radial highways
#  TAX    |  full-value property-tax rate per \$10,000
#  PTRATIO|  pupil-teacher ratio by town
#  B      |  1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#  LSTAT  |  % lower status of the population
#  MEDV   |  Median value of owner-occupied homes in $1000's

# %%
# Importamos el dataset para train y para test
from keras.datasets import boston_housing
(x_train, y_train), (x_test, y_test) = boston_housing.load_data(test_split=0.2,seed=10)
# test_split indica que el 20% del dataet sera usado como test
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step

# %%
#c Comprobamos el size de nuestros datasets
print("Tamaño set de entrenamiento:",x_train.shape)
print("Tamaño set de prueba:",x_test.shape)
# Out:
# Tamaño set de entrenamiento: (404, 13)
# Tamaño set de prueba: (102, 13)

# %%
# Verificamos el tipo de dato de nustro dataset
x_train[:1]
# Out:
# array([[5.4790e-02, 3.3000e+01, 2.1800e+00, 0.0000e+00, 4.7200e-01,
#         6.6160e+00, 5.8100e+01, 3.3700e+00, 7.0000e+00, 2.2200e+02,
#         1.8400e+01, 3.9336e+02, 8.9300e+00]])

# %% [markdown]
# Usaremos una arquitectura de 13 neuronas de entrada 1 capa oculta de 6, 1 oculta de 4 y una salida de 1 neurona

# %%
# Hacemos los imports
import numpy as np
from keras.models import Sequential # Permite construir capa a capa la red a implementar
from keras.layers import Dense, Activation # Capa densa donde todas neuronas conectadas a la siguiente capa

# %%
# Definición de la arquitectura
# Creamos la instancia para el modelo
model = Sequential()

# Agregamos las capas
model.add(Dense(13, input_dim=13, kernel_initializer='normal',activation='relu'))
model.add(Dense(6, kernel_initializer='normal',activation='relu'))
model.add(Dense(4, kernel_initializer='normal',activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))

# Compilación del modelo
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mean_absolute_percentage_error'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 13)                182
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 84
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 28
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 299
# Trainable params: 299
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png',show_shapes=True)

# %% [markdown]
# # <h1 id="keras">Entrenamiento y Evaluación del modelo</h1>
#
# Ahora realizaremos diferentes entrenamientos de la red neuronal diseña y evaluaremos su desempeño.

# %%
#Entrena el modelo
x_val = x_train[300:,] # variables
y_val = y_train[300:,] # Etiquetas

# %%
#Entrena el modelo con 5 epochs/iteraciones
model.fit(x_train, y_train, batch_size=32, epochs=5, validation_data=(x_val,y_val))
# Out:
# Epoch 1/5
# 13/13 [==============================] - 0s 13ms/step - loss: 590.0974 - mean_absolute_percentage_error: 99.9294 - val_loss: 535.8681 - val_mean_absolute_percentage_error: 99.8152
# Epoch 2/5
# 13/13 [==============================] - 0s 2ms/step - loss: 588.1282 - mean_absolute_percentage_error: 99.6813 - val_loss: 533.0748 - val_mean_absolute_percentage_error: 99.4281
# Epoch 3/5
# 13/13 [==============================] - 0s 2ms/step - loss: 583.4579 - mean_absolute_percentage_error: 99.0753 - val_loss: 525.3528 - val_mean_absolute_percentage_error: 98.3380
# Epoch 4/5
# 13/13 [==============================] - 0s 2ms/step - loss: 569.3726 - mean_absolute_percentage_error: 97.2705 - val_loss: 502.4033 - val_mean_absolute_percentage_error: 95.0447
# Epoch 5/5
# 13/13 [==============================] - 0s 2ms/step - loss: 530.3746 - mean_absolute_percentage_error: 92.0334 - val_loss: 443.8773 - val_mean_absolute_percentage_error: 86.1739

# %%
#Entrena el modelo con 100 epochs/iteraciones
model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data=(x_val,y_val))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 5ms/step - loss: 442.8238 - mean_absolute_percentage_error: 79.1604 - val_loss: 328.1358 - val_mean_absolute_percentage_error: 67.4302
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 296.6122 - mean_absolute_percentage_error: 57.4998 - val_loss: 179.5314 - val_mean_absolute_percentage_error: 45.4213
# Epoch 3/100
# 13/13 [==============================] - 0s 2ms/step - loss: 158.7015 - mean_absolute_percentage_error: 45.4622 - val_loss: 124.4881 - val_mean_absolute_percentage_error: 49.8827
# Epoch 4/100
# 13/13 [==============================] - 0s 2ms/step - loss: 135.9201 - mean_absolute_percentage_error: 52.0069 - val_loss: 126.3395 - val_mean_absolute_percentage_error: 52.6326
# Epoch 5/100
# 13/13 [==============================] - 0s 2ms/step - loss: 127.7608 - mean_absolute_percentage_error: 48.0156 - val_loss: 113.8594 - val_mean_absolute_percentage_error: 45.0333
# Epoch 6/100
# 13/13 [==============================] - 0s 2ms/step - loss: 122.6303 - mean_absolute_percentage_error: 43.9950 - val_loss: 109.8349 - val_mean_absolute_percentage_error: 44.4560
# Epoch 7/100
# 13/13 [==============================] - 0s 2ms/step - loss: 117.3668 - mean_absolute_percentage_error: 44.6635 - val_loss: 107.9920 - val_mean_absolute_percentage_error: 45.8164
# Epoch 8/100
# 13/13 [==============================] - 0s 2ms/step - loss: 113.1115 - mean_absolute_percentage_error: 44.0581 - val_loss: 102.8356 - val_mean_absolute_percentage_error: 43.5295
# Epoch 9/100
# 13/13 [==============================] - 0s 2ms/step - loss: 108.6723 - mean_absolute_percentage_error: 41.6404 - val_loss: 98.4151 - val_mean_absolute_percentage_error: 41.3737
# Epoch 10/100
# 13/13 [==============================] - 0s 2ms/step - loss: 105.2426 - mean_absolute_percentage_error: 39.8446 - val_loss: 95.0580 - val_mean_absolute_percentage_error: 40.3151
# Epoch 11/100
# 13/13 [==============================] - 0s 2ms/step - loss: 100.6812 - mean_absolute_percentage_error: 39.8542 - val_loss: 92.9170 - val_mean_absolute_percentage_error: 41.1023
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 97.4554 - mean_absolute_percentage_error: 39.7210 - val_loss: 89.2754 - val_mean_absolute_percentage_error: 39.7637
# Epoch 13/100
# 13/13 [==============================] - 0s 2ms/step - loss: 94.0011 - mean_absolute_percentage_error: 37.4879 - val_loss: 86.0469 - val_mean_absolute_percentage_error: 38.4974
# Epoch 14/100
# 13/13 [==============================] - 0s 2ms/step - loss: 90.7404 - mean_absolute_percentage_error: 37.3661 - val_loss: 83.7073 - val_mean_absolute_percentage_error: 38.6864
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 87.5096 - mean_absolute_percentage_error: 36.5913 - val_loss: 81.1334 - val_mean_absolute_percentage_error: 37.9811
# Epoch 16/100
# 13/13 [==============================] - 0s 2ms/step - loss: 84.8111 - mean_absolute_percentage_error: 35.6756 - val_loss: 78.6526 - val_mean_absolute_percentage_error: 37.1759
# Epoch 17/100
# 13/13 [==============================] - 0s 2ms/step - loss: 82.5516 - mean_absolute_percentage_error: 34.6239 - val_loss: 76.3640 - val_mean_absolute_percentage_error: 36.3427
# Epoch 18/100
# 13/13 [==============================] - 0s 3ms/step - loss: 79.9299 - mean_absolute_percentage_error: 35.0395 - val_loss: 75.6837 - val_mean_absolute_percentage_error: 37.6446
# Epoch 19/100
# 13/13 [==============================] - 0s 3ms/step - loss: 77.7881 - mean_absolute_percentage_error: 33.8161 - val_loss: 72.9700 - val_mean_absolute_percentage_error: 35.6902
# Epoch 20/100
# 13/13 [==============================] - 0s 2ms/step - loss: 75.6627 - mean_absolute_percentage_error: 32.9167 - val_loss: 71.5163 - val_mean_absolute_percentage_error: 35.4392
# Epoch 21/100
# 13/13 [==============================] - 0s 2ms/step - loss: 74.3651 - mean_absolute_percentage_error: 33.4479 - val_loss: 70.5772 - val_mean_absolute_percentage_error: 35.7958
# Epoch 22/100
# 13/13 [==============================] - 0s 2ms/step - loss: 72.3762 - mean_absolute_percentage_error: 31.9290 - val_loss: 69.0765 - val_mean_absolute_percentage_error: 34.4830
# Epoch 23/100
# 13/13 [==============================] - 0s 2ms/step - loss: 71.4598 - mean_absolute_percentage_error: 31.6441 - val_loss: 68.7142 - val_mean_absolute_percentage_error: 35.6016
# Epoch 24/100
# 13/13 [==============================] - 0s 2ms/step - loss: 70.6399 - mean_absolute_percentage_error: 31.5327 - val_loss: 67.7290 - val_mean_absolute_percentage_error: 34.8499
# Epoch 25/100
# 13/13 [==============================] - 0s 2ms/step - loss: 69.7142 - mean_absolute_percentage_error: 31.9539 - val_loss: 67.5196 - val_mean_absolute_percentage_error: 35.3051
# Epoch 26/100
# 13/13 [==============================] - 0s 2ms/step - loss: 69.0431 - mean_absolute_percentage_error: 32.4635 - val_loss: 67.5298 - val_mean_absolute_percentage_error: 35.9680
# Epoch 27/100
# 13/13 [==============================] - 0s 2ms/step - loss: 68.0632 - mean_absolute_percentage_error: 31.1927 - val_loss: 66.1033 - val_mean_absolute_percentage_error: 34.1363
# Epoch 28/100
# 13/13 [==============================] - 0s 2ms/step - loss: 67.6573 - mean_absolute_percentage_error: 30.4371 - val_loss: 65.8163 - val_mean_absolute_percentage_error: 34.5189
# Epoch 29/100
# 13/13 [==============================] - 0s 2ms/step - loss: 68.0383 - mean_absolute_percentage_error: 32.6828 - val_loss: 66.0705 - val_mean_absolute_percentage_error: 35.5536
# Epoch 30/100
# 13/13 [==============================] - 0s 2ms/step - loss: 66.8717 - mean_absolute_percentage_error: 30.1025 - val_loss: 64.5877 - val_mean_absolute_percentage_error: 33.1175
# Epoch 31/100
# 13/13 [==============================] - 0s 3ms/step - loss: 66.4219 - mean_absolute_percentage_error: 30.9226 - val_loss: 65.0093 - val_mean_absolute_percentage_error: 35.0028
# Epoch 32/100
# 13/13 [==============================] - 0s 2ms/step - loss: 65.4676 - mean_absolute_percentage_error: 30.3041 - val_loss: 63.7812 - val_mean_absolute_percentage_error: 33.6215
# Epoch 33/100
# 13/13 [==============================] - 0s 2ms/step - loss: 65.0932 - mean_absolute_percentage_error: 30.3110 - val_loss: 63.5736 - val_mean_absolute_percentage_error: 34.0385
# Epoch 34/100
# 13/13 [==============================] - 0s 2ms/step - loss: 64.4673 - mean_absolute_percentage_error: 29.5746 - val_loss: 62.8738 - val_mean_absolute_percentage_error: 33.4210
# Epoch 35/100
# 13/13 [==============================] - 0s 2ms/step - loss: 63.9795 - mean_absolute_percentage_error: 29.4716 - val_loss: 62.5818 - val_mean_absolute_percentage_error: 33.6723
# Epoch 36/100
# 13/13 [==============================] - 0s 2ms/step - loss: 63.6388 - mean_absolute_percentage_error: 30.2794 - val_loss: 62.0740 - val_mean_absolute_percentage_error: 33.4402
# Epoch 37/100
# 13/13 [==============================] - 0s 2ms/step - loss: 62.9235 - mean_absolute_percentage_error: 28.8654 - val_loss: 61.2515 - val_mean_absolute_percentage_error: 32.6270
# Epoch 38/100
# 13/13 [==============================] - 0s 2ms/step - loss: 62.4617 - mean_absolute_percentage_error: 28.5083 - val_loss: 60.7143 - val_mean_absolute_percentage_error: 32.5060
# Epoch 39/100
# 13/13 [==============================] - 0s 2ms/step - loss: 61.9380 - mean_absolute_percentage_error: 28.4823 - val_loss: 60.4552 - val_mean_absolute_percentage_error: 32.6167
# Epoch 40/100
# 13/13 [==============================] - 0s 4ms/step - loss: 61.4724 - mean_absolute_percentage_error: 28.6708 - val_loss: 59.8298 - val_mean_absolute_percentage_error: 32.2716
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 60.9892 - mean_absolute_percentage_error: 28.0614 - val_loss: 58.9840 - val_mean_absolute_percentage_error: 31.4180
# Epoch 42/100
# 13/13 [==============================] - 0s 3ms/step - loss: 60.7156 - mean_absolute_percentage_error: 27.9473 - val_loss: 58.8264 - val_mean_absolute_percentage_error: 31.6449
# Epoch 43/100
# 13/13 [==============================] - 0s 2ms/step - loss: 61.0624 - mean_absolute_percentage_error: 26.6302 - val_loss: 57.9386 - val_mean_absolute_percentage_error: 30.5269
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 60.1524 - mean_absolute_percentage_error: 28.4282 - val_loss: 58.6902 - val_mean_absolute_percentage_error: 32.2185
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 59.4822 - mean_absolute_percentage_error: 27.3486 - val_loss: 57.2589 - val_mean_absolute_percentage_error: 30.5087
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 59.2313 - mean_absolute_percentage_error: 26.7296 - val_loss: 57.1142 - val_mean_absolute_percentage_error: 30.9623
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 58.8270 - mean_absolute_percentage_error: 27.5931 - val_loss: 56.6550 - val_mean_absolute_percentage_error: 30.7664
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 58.7619 - mean_absolute_percentage_error: 26.1725 - val_loss: 56.0646 - val_mean_absolute_percentage_error: 29.9226
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 58.3906 - mean_absolute_percentage_error: 27.4472 - val_loss: 56.4836 - val_mean_absolute_percentage_error: 31.0610
# Epoch 50/100
# 13/13 [==============================] - 0s 2ms/step - loss: 57.7604 - mean_absolute_percentage_error: 26.9217 - val_loss: 55.5560 - val_mean_absolute_percentage_error: 29.9200
# Epoch 51/100
# 13/13 [==============================] - 0s 2ms/step - loss: 57.7807 - mean_absolute_percentage_error: 25.8632 - val_loss: 55.2013 - val_mean_absolute_percentage_error: 29.5973
# Epoch 52/100
# 13/13 [==============================] - 0s 2ms/step - loss: 57.2361 - mean_absolute_percentage_error: 26.7092 - val_loss: 55.7126 - val_mean_absolute_percentage_error: 30.9183
# Epoch 53/100
# 13/13 [==============================] - 0s 2ms/step - loss: 57.3506 - mean_absolute_percentage_error: 26.7871 - val_loss: 54.4931 - val_mean_absolute_percentage_error: 29.2288
# Epoch 54/100
# 13/13 [==============================] - 0s 2ms/step - loss: 56.8114 - mean_absolute_percentage_error: 25.7897 - val_loss: 55.1015 - val_mean_absolute_percentage_error: 30.5650
# Epoch 55/100
# 13/13 [==============================] - 0s 2ms/step - loss: 56.6963 - mean_absolute_percentage_error: 26.2816 - val_loss: 54.2552 - val_mean_absolute_percentage_error: 29.7064
# Epoch 56/100
# 13/13 [==============================] - 0s 2ms/step - loss: 57.0707 - mean_absolute_percentage_error: 27.0923 - val_loss: 53.9762 - val_mean_absolute_percentage_error: 29.4405
# Epoch 57/100
# 13/13 [==============================] - 0s 2ms/step - loss: 56.3133 - mean_absolute_percentage_error: 25.4241 - val_loss: 53.7862 - val_mean_absolute_percentage_error: 29.5824
# Epoch 58/100
# 13/13 [==============================] - 0s 2ms/step - loss: 55.8946 - mean_absolute_percentage_error: 26.0200 - val_loss: 54.0259 - val_mean_absolute_percentage_error: 30.1655
# Epoch 59/100
# 13/13 [==============================] - 0s 2ms/step - loss: 55.7222 - mean_absolute_percentage_error: 26.3852 - val_loss: 53.3461 - val_mean_absolute_percentage_error: 29.4644
# Epoch 60/100
# 13/13 [==============================] - 0s 2ms/step - loss: 55.3297 - mean_absolute_percentage_error: 25.4550 - val_loss: 52.7551 - val_mean_absolute_percentage_error: 28.3254
# Epoch 61/100
# 13/13 [==============================] - 0s 2ms/step - loss: 56.2028 - mean_absolute_percentage_error: 26.2814 - val_loss: 52.8777 - val_mean_absolute_percentage_error: 29.2258
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 54.9489 - mean_absolute_percentage_error: 24.9940 - val_loss: 52.2766 - val_mean_absolute_percentage_error: 28.1872
# Epoch 63/100
# 13/13 [==============================] - 0s 2ms/step - loss: 55.0092 - mean_absolute_percentage_error: 25.9988 - val_loss: 52.6078 - val_mean_absolute_percentage_error: 29.4250
# Epoch 64/100
# 13/13 [==============================] - 0s 2ms/step - loss: 54.4444 - mean_absolute_percentage_error: 25.4095 - val_loss: 52.1458 - val_mean_absolute_percentage_error: 28.8685
# Epoch 65/100
# 13/13 [==============================] - 0s 2ms/step - loss: 54.3029 - mean_absolute_percentage_error: 24.9999 - val_loss: 51.9394 - val_mean_absolute_percentage_error: 28.7829
# Epoch 66/100
# 13/13 [==============================] - 0s 2ms/step - loss: 54.1114 - mean_absolute_percentage_error: 25.6237 - val_loss: 51.8506 - val_mean_absolute_percentage_error: 28.9228
# Epoch 67/100
# 13/13 [==============================] - 0s 2ms/step - loss: 53.8250 - mean_absolute_percentage_error: 25.0216 - val_loss: 51.5930 - val_mean_absolute_percentage_error: 28.7660
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 53.5780 - mean_absolute_percentage_error: 25.5288 - val_loss: 51.7767 - val_mean_absolute_percentage_error: 29.2984
# Epoch 69/100
# 13/13 [==============================] - 0s 2ms/step - loss: 53.5171 - mean_absolute_percentage_error: 25.5105 - val_loss: 51.0100 - val_mean_absolute_percentage_error: 28.2383
# Epoch 70/100
# 13/13 [==============================] - 0s 2ms/step - loss: 53.4839 - mean_absolute_percentage_error: 24.1688 - val_loss: 50.9109 - val_mean_absolute_percentage_error: 28.5142
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 53.0539 - mean_absolute_percentage_error: 24.9103 - val_loss: 50.6992 - val_mean_absolute_percentage_error: 28.3502
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 52.7118 - mean_absolute_percentage_error: 24.8401 - val_loss: 50.7921 - val_mean_absolute_percentage_error: 28.8083
# Epoch 73/100
# 13/13 [==============================] - 0s 2ms/step - loss: 52.9002 - mean_absolute_percentage_error: 24.4800 - val_loss: 50.3339 - val_mean_absolute_percentage_error: 28.4517
# Epoch 74/100
# 13/13 [==============================] - 0s 2ms/step - loss: 52.4613 - mean_absolute_percentage_error: 25.8687 - val_loss: 50.5032 - val_mean_absolute_percentage_error: 28.8699
# Epoch 75/100
# 13/13 [==============================] - 0s 2ms/step - loss: 52.5839 - mean_absolute_percentage_error: 23.8432 - val_loss: 49.6093 - val_mean_absolute_percentage_error: 27.4505
# Epoch 76/100
# 13/13 [==============================] - 0s 2ms/step - loss: 51.9679 - mean_absolute_percentage_error: 25.1049 - val_loss: 50.0195 - val_mean_absolute_percentage_error: 28.7080
# Epoch 77/100
# 13/13 [==============================] - 0s 2ms/step - loss: 51.7085 - mean_absolute_percentage_error: 24.6234 - val_loss: 49.4433 - val_mean_absolute_percentage_error: 28.1750
# Epoch 78/100
# 13/13 [==============================] - 0s 2ms/step - loss: 51.3177 - mean_absolute_percentage_error: 24.0639 - val_loss: 48.9850 - val_mean_absolute_percentage_error: 27.6663
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 51.1074 - mean_absolute_percentage_error: 24.9531 - val_loss: 49.3619 - val_mean_absolute_percentage_error: 28.5122
# Epoch 80/100
# 13/13 [==============================] - 0s 2ms/step - loss: 50.7940 - mean_absolute_percentage_error: 24.1458 - val_loss: 48.5678 - val_mean_absolute_percentage_error: 27.3654
# Epoch 81/100
# 13/13 [==============================] - 0s 2ms/step - loss: 50.9330 - mean_absolute_percentage_error: 23.7023 - val_loss: 48.8133 - val_mean_absolute_percentage_error: 28.3236
# Epoch 82/100
# 13/13 [==============================] - 0s 2ms/step - loss: 51.0672 - mean_absolute_percentage_error: 23.7971 - val_loss: 48.5984 - val_mean_absolute_percentage_error: 28.2373
# Epoch 83/100
# 13/13 [==============================] - 0s 2ms/step - loss: 50.2651 - mean_absolute_percentage_error: 24.6699 - val_loss: 48.0599 - val_mean_absolute_percentage_error: 27.7017
# Epoch 84/100
# 13/13 [==============================] - 0s 2ms/step - loss: 49.9730 - mean_absolute_percentage_error: 23.5599 - val_loss: 47.7608 - val_mean_absolute_percentage_error: 27.4593
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 49.8041 - mean_absolute_percentage_error: 24.2110 - val_loss: 47.5132 - val_mean_absolute_percentage_error: 27.3110
# Epoch 86/100
# 13/13 [==============================] - 0s 2ms/step - loss: 49.8647 - mean_absolute_percentage_error: 24.7036 - val_loss: 47.5033 - val_mean_absolute_percentage_error: 27.6950
# Epoch 87/100
# 13/13 [==============================] - 0s 3ms/step - loss: 49.6367 - mean_absolute_percentage_error: 22.8912 - val_loss: 46.8039 - val_mean_absolute_percentage_error: 26.7755
# Epoch 88/100
# 13/13 [==============================] - 0s 2ms/step - loss: 49.4058 - mean_absolute_percentage_error: 24.2877 - val_loss: 46.6811 - val_mean_absolute_percentage_error: 26.9948
# Epoch 89/100
# 13/13 [==============================] - 0s 2ms/step - loss: 48.6106 - mean_absolute_percentage_error: 23.3851 - val_loss: 46.4991 - val_mean_absolute_percentage_error: 27.0106
# Epoch 90/100
# 13/13 [==============================] - 0s 2ms/step - loss: 48.3668 - mean_absolute_percentage_error: 23.4346 - val_loss: 46.4784 - val_mean_absolute_percentage_error: 27.2357
# Epoch 91/100
# 13/13 [==============================] - 0s 2ms/step - loss: 48.1092 - mean_absolute_percentage_error: 23.3192 - val_loss: 45.8633 - val_mean_absolute_percentage_error: 26.4788
# Epoch 92/100
# 13/13 [==============================] - 0s 2ms/step - loss: 47.8380 - mean_absolute_percentage_error: 23.1744 - val_loss: 46.0110 - val_mean_absolute_percentage_error: 27.3048
# Epoch 93/100
# 13/13 [==============================] - 0s 2ms/step - loss: 47.7503 - mean_absolute_percentage_error: 23.6892 - val_loss: 45.7049 - val_mean_absolute_percentage_error: 27.0915
# Epoch 94/100
# 13/13 [==============================] - 0s 2ms/step - loss: 47.3305 - mean_absolute_percentage_error: 23.0760 - val_loss: 45.0214 - val_mean_absolute_percentage_error: 26.2681
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 47.3836 - mean_absolute_percentage_error: 23.3878 - val_loss: 45.4954 - val_mean_absolute_percentage_error: 27.4132
# Epoch 96/100
# 13/13 [==============================] - 0s 2ms/step - loss: 46.7431 - mean_absolute_percentage_error: 22.7488 - val_loss: 44.4222 - val_mean_absolute_percentage_error: 25.8758
# Epoch 97/100
# 13/13 [==============================] - 0s 2ms/step - loss: 46.4983 - mean_absolute_percentage_error: 22.5791 - val_loss: 44.8244 - val_mean_absolute_percentage_error: 27.0766
# Epoch 98/100
# 13/13 [==============================] - 0s 2ms/step - loss: 46.4458 - mean_absolute_percentage_error: 23.2738 - val_loss: 44.1585 - val_mean_absolute_percentage_error: 26.2452
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 45.9007 - mean_absolute_percentage_error: 23.0530 - val_loss: 43.9754 - val_mean_absolute_percentage_error: 26.3575
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 45.5804 - mean_absolute_percentage_error: 22.5834 - val_loss: 43.5415 - val_mean_absolute_percentage_error: 25.8672

# %%
# Realizamos la evaluacion los datos de prueba
results = model.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 43.1649 - mean_absolute_percentage_error: 19.0830

# %%
results
# Out:
# [43.16485595703125, 19.08304214477539]

# %% [markdown]
# # Visualizando el proceso de entrenamiento

# %% [markdown]
# Vamos a evaluar la historia del entrenamiento mediante las distintas epocas.

# %%
history = model.fit(x_train, y_train, batch_size=32, epochs=200,validation_data=(x_val,y_val), verbose=0)
#verbose=0 evita imprimir en pantalla el output de los trainings

# %%
# Plotting process
import matplotlib.pyplot as plt

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(13,6))
plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model mean_absolute_percentage_error')
plt.ylabel('MAPE %')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
#Comparamos la funcion de perdida loss, indica en que direccion el algoritmo tiene 
# que enforcarse para aprender mas sobre los datos

plt.figure(figsize=(13,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
